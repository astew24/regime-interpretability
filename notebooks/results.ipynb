# %% [markdown]
# # Regime Interpretability Results

# %% [markdown]
# ## Data Overview

# %%
# TODO: Load processed prices and return windows.

# %% [markdown]
# ## Autoencoder Training

# %%
# TODO: Review dense autoencoder losses and embeddings.

# %% [markdown]
# ## Sparse Feature Analysis

# %%
# TODO: Inspect sparse activations and feature labels.

# %% [markdown]
# ## Baseline Comparison

# %%
# TODO: Compare HMM and KMeans transition timing.
